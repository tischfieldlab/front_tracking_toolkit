# %%
from front_tracking_toolkit.experiment import ExperimentConfig, Experiment
import matplotlib.pyplot as plt
from front_tracking_toolkit.plotting import plot_spatial_velocity_hexbin

# %%
config = ExperimentConfig()
config.stains = ['Dextran', 'OVA']
config.basedir = r'F:\Max_FrontTracking\test_experiment1'
config.result_pattern = 'results3/{sample}/{stain}/vf.csv'
config.data_pattern = 'data/{sample}/{stain}/processed/*.tif'

# %%
exp = Experiment(config)
# Out:
# Excluding metadata rows where "Exclude" == "YES"
# F:\Max_FrontTracking\test_experiment1\results3/898/Dextran/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/898/OVA/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/900/Dextran/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/900/OVA/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/903/Dextran/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/903/OVA/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/904/Dextran/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/904/OVA/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/905/Dextran/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/905/OVA/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/906/Dextran/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/906/OVA/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/909/Dextran/vf.csv
# F:\Max_FrontTracking\test_experiment1\results3/909/OVA/vf.csv
# ...

# %%
plot_spatial_velocity_hexbin(exp)
# Out:
# (<Figure size 576x1800 with 21 Axes>,
#  array([[<AxesSubplot:title={'center':'898 (HET): Dextran'}>,
#          <AxesSubplot:title={'center':'898 (HET): OVA'}>],
#         [<AxesSubplot:title={'center':'900 (HET): Dextran'}>,
#          <AxesSubplot:title={'center':'900 (HET): OVA'}>],
#         [<AxesSubplot:title={'center':'903 (HET): Dextran'}>,
#          <AxesSubplot:title={'center':'903 (HET): OVA'}>],
#         [<AxesSubplot:title={'center':'904 (WT): Dextran'}>,
#          <AxesSubplot:title={'center':'904 (WT): OVA'}>],
#         [<AxesSubplot:title={'center':'905 (WT): Dextran'}>,
#          <AxesSubplot:title={'center':'905 (WT): OVA'}>],
#         [<AxesSubplot:title={'center':'906 (WT): Dextran'}>,
#          <AxesSubplot:title={'center':'906 (WT): OVA'}>],
#         [<AxesSubplot:title={'center':'909 (HET): Dextran'}>,
#          <AxesSubplot:title={'center':'909 (HET): OVA'}>],
#         [<AxesSubplot:title={'center':'4.14.21 Injection 2 (WT): Dextran'}>,
# ...
